# %% [markdown]
# ## logistic regression multi-dimensional data

# %% [markdown]
#  logistic regression multi-dimensional data
#
#
#  $$ F(X)=X \times W $$
#  $$ H(x)= \frac{1}{1+ e ^{-F(x)}} $$
#  $$ C= -\frac{1}{n} \sum_{i,j} (Y \odot log(H(x)) + (1-Y) \odot log(1-H(x)) ) $$
#
# $X_{n \times k}$
#
# $W_{k \times p}$
#
# $Y_{n \times p}$

# %%
import numpy as np
import random

# %%
n, k, p=100, 8, 3

# %%
X=np.random.random([n,k])
W=np.random.random([k,p])

y=np.random.randint(p, size=(1,n))
Y=np.zeros((n,p))
Y[np.arange(n), y]=1

max_itr=5000
alpha=0.01
Lambda=0.01

# %% [markdown]
# Gradient is as follows:
# $$ X^T (H(x)-Y) + \lambda 2 W$$

# %%
# F(x)= w[0]*x + w[1]
def F(X, W):
    return np.matmul(X,W)

def H(F):
    return 1/(1+np.exp(-F))

def cost(Y_est, Y):
    E= - (1/n) * (np.sum(Y*np.log(Y_est) + (1-Y)*np.log(1-Y_est)))  + np.linalg.norm(W,2)
    return E, np.sum(np.argmax(Y_est,1)==y)/n

def gradient(Y_est, Y, X):
    return (1/n) * np.matmul(X.T, (Y_est - Y) ) + Lambda* 2* W

# %%
def fit(W, X, Y, alpha, max_itr):
    for i in range(max_itr):
        
        F_x=F(X,W)
        Y_est=H(F_x)
        E, c= cost(Y_est, Y)
        Wg=gradient(Y_est, Y, X)
        W=W - alpha * Wg
        if i%100==0:
            print(E, c)
        
    return W, Y_est

# %% [markdown]
# To take into account for the biases, we concatenate X by a 1 column, and increase the number of rows in W by one

# %%
X=np.concatenate( (X, np.ones((n,1))), axis=1 ) 
W=np.concatenate( (W, np.random.random((1,p)) ), axis=0 )

W, Y_est = fit(W, X, Y, alpha, max_itr)
# Out:
# 6.718996914758343 0.3
# 4.820471171494192 0.36
# 4.318936523202406 0.38
# 4.218780306307605 0.42
# 4.197294212201086 0.44
# 4.191208347293338 0.44
# 4.188063539520591 0.45
# 4.185373731746892 0.45
# 4.182709348857521 0.45
# 4.180046614167144 0.45
# 4.1774200627910165 0.45
# 4.174857733252697 0.46
# 4.172375257807301 0.46
# 4.169979645990572 0.46
# 4.167672954582862 0.45
# 4.1654546110071875 0.45
# 4.163322716369359 0.46
# 4.161274740671397 0.46
# 4.159307884770626 0.45
# 4.157419266030563 0.46
# 4.155606012237945 0.46
# 4.15386530817463 0.48
# 4.152194417855384 0.48
# 4.1505906942922 0.49
# 4.149051582883661 0.5
# 4.147574621562894 0.51
# 4.146157439314604 0.5
# 4.1447977538896685 0.5
# 4.143493369144091 0.5
# 4.142242172222593 0.5
# 4.141042130700821 0.5
# 4.139891289745262 0.5
# 4.138787769321565 0.48
# 4.137729761467164 0.48
# 4.136715527636316 0.48
# 4.13574339612153 0.48
# 4.134811759553116 0.47
# 4.133919072477272 0.47
# 4.133063849012423 0.47
# 4.13224466058305 0.46
# 4.131460133729893 0.46
# 4.130708947995285 0.47
# 4.129989833882121 0.47
# 4.1293015708849135 0.47
# 4.128642985591279 0.47
# 4.128012949852103 0.47
# 4.127410379018622 0.47
# 4.126834230244591 0.47
# 4.126283500851695 0.46
# 4.125757226756343 0.45

#        [0.36969982, 0.32745732, 0.25546968],
#        [0.34644119, 0.28894223, 0.35185727],
#        [0.36632843, 0.26329483, 0.27521856],
#        [0.46348087, 0.23067438, 0.26335793],
#        [0.35951969, 0.27116458, 0.349073  ],
#        [0.450425  , 0.30128915, 0.21561116],
#        [0.37937889, 0.28338749, 0.25939021],
#        [0.54929583, 0.24182261, 0.21095786],
#        [0.4530228 , 0.23077125, 0.28782373],
#        [0.35261695, 0.32093846, 0.34786657],
#        [0.39733821, 0.34780428, 0.22822617],
#        [0.38325453, 0.23523174, 0.37928959],
#        [0.48832628, 0.25863652, 0.29030719],
#        [0.45226794, 0.27829704, 0.34520319],
#        [0.42005643, 0.30825701, 0.22927886],
#        [0.28553981, 0.37411962, 0.37874479],
#        [0.34632786, 0.36284761, 0.26418303],
#        [0.45165411, 0.34921451, 0.19650478],
#        [0.45967503, 0.2697934 , 0.23535661],
#        [0.3654261 , 0.32611751, 0.31407308],
#        [0.29399066, 0.32243022, 0.26056508],
#        [0.52380564, 0.22595442, 0.27455506],
#        [0.19673635, 0.34316056, 0.42119054],
#        [0.30990564, 0.24922137, 0.41233741],
#        [0.39621417, 0.3458847 , 0.28122629],
#        [0.28065289, 0.27640873, 0.34844618],
#        [0.35153723, 0.28343706, 0.36424248],
#        [0.58096893, 0.24121027, 0.19744434],
#        [0.43021884, 0.26121724, 0.20281091],
#        [0.45947851, 0.28893463, 0.20741019],
#        [0.36376152, 0.36832241, 0.27403821],
#        [0.49169219, 0.24991059, 0.22961014],
#        [0.23818024, 0.3298958 , 0.32037339],
#        [0.50859911, 0.21386884, 0.23778173],
#        [0.4663517 , 0.20932852, 0.26250863],
#        [0.39715224, 0.32149806, 0.29572006],
#        [0.3310048 , 0.24544353, 0.28340374],
#        [0.22107405, 0.33784111, 0.37389549],
#        [0.5649068 , 0.22355613, 0.30794851],
#        [0.28723742, 0.27532902, 0.39266993],
#        [0.3893323 , 0.27806952, 0.27918867],
#        [0.25980108, 0.35199724, 0.32948416],
#        [0.41225734, 0.31848779, 0.21159474],
#        [0.33099036, 0.23912713, 0.3577929 ],
#        [0.38359421, 0.26103673, 0.22405889],
#        [0.43099084, 0.23289261, 0.24165609],
#        [0.27826802, 0.27681361, 0.2836174 ],
#        [0.33026233, 0.35039456, 0.28502007],
#        [0.27799668, 0.29821246, 0.41467936],
#        [0.29457702, 0.33712264, 0.32758603],
#        [0.55292477, 0.2954868 , 0.1928526 ],
#        [0.3800748 , 0.37234875, 0.36329535],
#        [0.43961252, 0.32486173, 0.2964035 ],
#        [0.2918412 , 0.3085837 , 0.33504458],
#        [0.40359816, 0.25446022, 0.20311548],
#        [0.41399422, 0.32062754, 0.29470382],
#        [0.30984864, 0.27732521, 0.40473371],
#        [0.49431799, 0.28860146, 0.23978018],
#        [0.39367441, 0.36467236, 0.30048344],
#        [0.3643245 , 0.30682092, 0.22559006],
#        [0.30849554, 0.2495531 , 0.24796748],
#        [0.38992477, 0.26638032, 0.31161985],
#        [0.57574866, 0.21478265, 0.20386861],
#        [0.40997264, 0.33758291, 0.37066872],
#        [0.39315335, 0.31833475, 0.29512793],
#        [0.41253755, 0.32032773, 0.21844442]])
